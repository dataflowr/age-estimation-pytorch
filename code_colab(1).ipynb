# %%
% cd drive/MyDrive/Project-age-estimation-pytorch-master/
# Out:
# /content/drive/MyDrive/Project-age-estimation-pytorch-master
# /content/drive/MyDrive/Project-age-estimation-pytorch-master

# %%
# !pip install better_exceptions
# !pip install pretrainedmodels
# !pip install yacs
# Out:
# ...
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.7/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/cli/base_command.py", line 153, in _main
#     status = self.run(options, args)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 438, in run
#     self._warn_about_conflicts(to_install)
#   File "/usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py", line 568, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
# ...

# %%
# !python train.py --data_dir appa-real-release --tensorboard tf_logD
# Out:
# Streaming output truncated to the last 5000 lines.
#  13% 4/31 [00:23<03:21,  7.47s/it, stage=train, epoch=3, loss=0.0321, acc=0.0332, correct=4, sample_num=128]torch.Size([128, 3, 224, 224]) torch.Size([128])
# forward_passed
#  16% 5/31 [00:25<02:29,  5.74s/it, stage=train, epoch=3, loss=0.0321, acc=0.0297, correct=2, sample_num=128]torch.Size([128, 3, 224, 224]) torch.Size([128])
# forward_passed
#  19% 6/31 [00:26<01:52,  4.51s/it, stage=train, epoch=3, loss=0.0321, acc=0.0339, correct=7, sample_num=128]torch.Size([128, 3, 224, 224]) torch.Size([128])
# forward_passed
#  23% 7/31 [00:28<01:27,  3.65s/it, stage=train, epoch=3, loss=0.032, acc=0.0324, correct=3, sample_num=128]torch.Size([128, 3, 224, 224]) torch.Size([128])
# forward_passed
#  26% 8/31 [00:30<01:10,  3.05s/it, stage=train, epoch=3, loss=0.032, acc=0.0332, correct=5, sample_num=128]torch.Size([128, 3, 224, 224]) torch.Size([128])
# forward_passed
# ...
